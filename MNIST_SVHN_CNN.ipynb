# %%
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

from torchvision import datasets
import torchvision.transforms as T

# %%
# Created modules
import visualization_utils as vu
import train_utils as tu
import model_utils as mu

import imp
imp.reload(mu)
imp.reload(tu)
# Out:
# <module 'train_utils' from '/Users/intanmaharani/Desktop/Semester I August 2022/IF5171 - Pembelajaran Mesin DSAI/Deep Learning/Praktikum_Mandiri/Project1/deliverables/train_utils.py'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 0. Defining Costants

# %%
DATA_DIR = "../data"
MODEL_DIR = "models"

EPOCHS = 10
BATCH_SIZE = 64
LEARNING_RATE = 1e-3

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
## Create the directory to store the model if not exists
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# Plotting Helper Function
def plot_acc_epoch(epochs, train_acc, test_acc):
    l = range(1,epochs+1)
    N = len(l)
    l2 = np.arange(N)
    plt.subplots(figsize=(10, 5))
    plt.plot(l2, test_acc, label="Testing Accuracy")
    plt.plot(l2, train_acc, label="Training Accuracy")
    plt.xticks(l2,l)
    plt.grid(True)
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title('Accuracy versus Epoch CNN Model', fontsize=12)
    plt.show()

# %% [markdown]
# ## 1. Dataset Preparation - MNIST for Training and SVHN for Testing

# %%
# Load dataset
training_data = datasets.MNIST(
    root=DATA_DIR, 
    train=True, 
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)
test_data = datasets.SVHN(
    root=DATA_DIR,
    split='test',
    download=True,
    transform = T.Compose([
        T.Resize((28,28)),
        T.Grayscale(),
        T.ToTensor(),
        T.Normalize([0.5],[0.5])
    ])
)
# Out:
# Using downloaded and verified file: ../data/test_32x32.mat

# %%
# Create data loaders
train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %% [markdown]
# Show the MNIST dataset

# %%
grid_tr = vu.set_grid(train_dataloader.dataset.data, num_cells=56)
vu.show(grid_tr)

# %%
grid_ts = vu.set_grid(test_dataloader.dataset.data, num_cells=56)
vu.show(grid_ts)

# %% [markdown]
# In this case study, both training data and test data are from the same domain - MNIST datasets. Therefore, as we can see, both data are quite similar in terms of its representation.

# %% [markdown]
# # 2. Modeling

# %% [markdown]
# The model that will be used is **CNN** or Convolutional Neural Network.
#
# For the loss/objective function, **Cross Entropy Loss** will be used. This loss function is used mainly because in our training, model weights will be adjusted in every epoch.
#
# For the optimizer, **Adam** will be used in the model development.

# %% [markdown]
# ### 2.1. Create the model

# %%
print(f"Using {DEVICE} device")

# Define model
cnn = mu.ConvNet(d_out=10).to(DEVICE)
print(cnn)

# Persistent file to store the model
model_path_adam = os.path.join(MODEL_DIR, "cnn_mnist_svhn_adam.pth")
# Out:
# Using cpu device
# ConvNet(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=128, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# ### 2.2. Define the loss function and the optimizers

# %%
# Loss function: Cross Entropy Loss or Log Loss
loss_fn = nn.CrossEntropyLoss()

# %%
# # Optimizer 1: Stochastic Gradient Descent (SGD)
# optimizer1 = optim.SGD(
#     cnn.parameters(), 
#     lr=LEARNING_RATE
# )

# %%
# Optimizer 2: Adam
optimizer2 = optim.Adam(
    cnn.parameters(), 
    lr=LEARNING_RATE
)

# %% [markdown]
# ### 2.3. Execute the training
#
# with **10** epochs for each experiment, **64** batch size, and **0.001** learning rate

# %% [markdown]
# #### 2.3.1. Using Adam as optimizer

# %%
test_accuracy_adam = []
train_accuracy_adam = []
for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train(train_dataloader, cnn, loss_fn, optimizer2)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    print("Test Set Error:")
    acc_test = tu.test(test_dataloader, cnn, loss_fn)
    print("\nTrain Set Error:")
    acc_train = tu.test(train_dataloader, cnn, loss_fn)
    test_accuracy_adam.append(acc_test)
    train_accuracy_adam.append(acc_train)
    
    # Save model
    torch.save(cnn.state_dict(), model_path_adam)
    print(f"Model {model_path_adam} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 10
#  ------------
# Loss: 2.309209 [    0]/60000
# Loss: 0.202421 [ 6400]/60000
# Loss: 0.143031 [12800]/60000
# Loss: 0.151129 [19200]/60000
# Loss: 0.060193 [25600]/60000
# Loss: 0.086679 [32000]/60000
# Loss: 0.062501 [38400]/60000
# Loss: 0.126522 [44800]/60000
# Loss: 0.246112 [51200]/60000
# Loss: 0.187882 [57600]/60000
#  > Training time: 114.71 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 26.7%, Avg loss: 4.096351
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.057608
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 2 out of 10
#  ------------
# Loss: 0.021728 [    0]/60000
# Loss: 0.143109 [ 6400]/60000
# Loss: 0.031630 [12800]/60000
# Loss: 0.010461 [19200]/60000
# Loss: 0.024858 [25600]/60000
# Loss: 0.076084 [32000]/60000
# Loss: 0.079114 [38400]/60000
# Loss: 0.083222 [44800]/60000
# Loss: 0.104108 [51200]/60000
# Loss: 0.060491 [57600]/60000
#  > Training time: 118.47 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 26.0%, Avg loss: 5.277574
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 98.7%, Avg loss: 0.041936
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 3 out of 10
#  ------------
# Loss: 0.016097 [    0]/60000
# Loss: 0.105617 [ 6400]/60000
# Loss: 0.026262 [12800]/60000
# Loss: 0.003583 [19200]/60000
# Loss: 0.027580 [25600]/60000
# Loss: 0.106709 [32000]/60000
# Loss: 0.031042 [38400]/60000
# Loss: 0.009687 [44800]/60000
# Loss: 0.008638 [51200]/60000
# Loss: 0.055374 [57600]/60000
#  > Training time: 119.53 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 25.2%, Avg loss: 5.626503
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.028180
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 4 out of 10
#  ------------
# Loss: 0.008335 [    0]/60000
# Loss: 0.075121 [ 6400]/60000
# Loss: 0.097436 [12800]/60000
# Loss: 0.009970 [19200]/60000
# Loss: 0.017339 [25600]/60000
# Loss: 0.010324 [32000]/60000
# Loss: 0.063242 [38400]/60000
# Loss: 0.013187 [44800]/60000
# Loss: 0.084718 [51200]/60000
# Loss: 0.004249 [57600]/60000
#  > Training time: 120.04 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 26.6%, Avg loss: 6.122305
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.026527
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 5 out of 10
#  ------------
# Loss: 0.008132 [    0]/60000
# Loss: 0.046161 [ 6400]/60000
# Loss: 0.032143 [12800]/60000
# Loss: 0.012325 [19200]/60000
# Loss: 0.003795 [25600]/60000
# Loss: 0.045990 [32000]/60000
# Loss: 0.008027 [38400]/60000
# Loss: 0.016926 [44800]/60000
# Loss: 0.077830 [51200]/60000
# Loss: 0.009514 [57600]/60000
#  > Training time: 118.20 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 26.7%, Avg loss: 7.729349
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.020145
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 6 out of 10
#  ------------
# Loss: 0.003000 [    0]/60000
# Loss: 0.063588 [ 6400]/60000
# Loss: 0.006418 [12800]/60000
# Loss: 0.043622 [19200]/60000
# Loss: 0.010652 [25600]/60000
# Loss: 0.064120 [32000]/60000
# Loss: 0.013295 [38400]/60000
# Loss: 0.015746 [44800]/60000
# Loss: 0.048919 [51200]/60000
# Loss: 0.039357 [57600]/60000
#  > Training time: 116.87 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 27.0%, Avg loss: 8.623349
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.029760
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 7 out of 10
#  ------------
# Loss: 0.011478 [    0]/60000
# Loss: 0.002214 [ 6400]/60000
# Loss: 0.043887 [12800]/60000
# Loss: 0.014776 [19200]/60000
# Loss: 0.016484 [25600]/60000
# Loss: 0.013681 [32000]/60000
# Loss: 0.041251 [38400]/60000
# Loss: 0.039855 [44800]/60000
# Loss: 0.013231 [51200]/60000
# Loss: 0.004976 [57600]/60000
#  > Training time: 118.53 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 27.0%, Avg loss: 12.866287
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.0%, Avg loss: 0.033676
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 8 out of 10
#  ------------
# Loss: 0.014235 [    0]/60000
# Loss: 0.017281 [ 6400]/60000
# Loss: 0.088817 [12800]/60000
# Loss: 0.042839 [19200]/60000
# Loss: 0.000455 [25600]/60000
# Loss: 0.024144 [32000]/60000
# Loss: 0.000444 [38400]/60000
# Loss: 0.020040 [44800]/60000
# Loss: 0.000434 [51200]/60000
# Loss: 0.023749 [57600]/60000
#  > Training time: 120.06 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 30.1%, Avg loss: 10.141757
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.012576
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 9 out of 10
#  ------------
# Loss: 0.004543 [    0]/60000
# Loss: 0.005857 [ 6400]/60000
# Loss: 0.006633 [12800]/60000
# Loss: 0.007546 [19200]/60000
# Loss: 0.077519 [25600]/60000
# Loss: 0.002412 [32000]/60000
# Loss: 0.010715 [38400]/60000
# Loss: 0.098253 [44800]/60000
# Loss: 0.055239 [51200]/60000
# Loss: 0.004948 [57600]/60000
#  > Training time: 118.93 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 30.8%, Avg loss: 9.591157
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.1%, Avg loss: 0.029910
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 10 out of 10
#  ------------
# Loss: 0.057694 [    0]/60000
# Loss: 0.001173 [ 6400]/60000
# Loss: 0.069608 [12800]/60000
# Loss: 0.000807 [19200]/60000
# Loss: 0.083803 [25600]/60000
# Loss: 0.093532 [32000]/60000
# Loss: 0.035823 [38400]/60000
# Loss: 0.001094 [44800]/60000
# Loss: 0.001571 [51200]/60000
# Loss: 0.055479 [57600]/60000
#  > Training time: 118.21 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 28.6%, Avg loss: 13.186245
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.025442
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Done!

# %% [markdown]
# **Experiment result**: from the above training and testing executions, it can be seen that the accuracy of the CNN model with Adam optimizer (10 epochs, 64 batch size, and 0.001 learning rate) is 28.6%.

# %% [markdown]
# ##### 2.3.1.1. Plotting Training Accuracy vs Test Accuracy

# %%
plot_acc_epoch(EPOCHS, train_accuracy_adam, test_accuracy_adam)

# %% [markdown]
# Using transformed SVHN dataset as test data when the CNN model is trained using MNIST dataset gives a quite low accuracy in testing - a big gap in fact as the plot above shows.
