# %%
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

from torchvision import datasets
import torchvision.transforms as T

# %%
# Created modules
import visualization_utils as vu
import train_utils as tu
import model_utils as mu

import imp
imp.reload(mu)
imp.reload(tu)
# Out:
# <module 'train_utils' from '/Users/intanmaharani/Desktop/Semester I August 2022/IF5171 - Pembelajaran Mesin DSAI/Deep Learning/Praktikum_Mandiri/Project1/deliverables/train_utils.py'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 0. Defining Costants

# %%
DATA_DIR = "../data"
MODEL_DIR = "models"

EPOCHS = 10
BATCH_SIZE = 64
LEARNING_RATE = 1e-3

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
## Create the directory to store the model if not exists
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# Plotting Helper Function
def plot_acc_epoch(epochs, train_acc, test_acc):
    l = range(1,epochs+1)
    N = len(l)
    l2 = np.arange(N)
    plt.subplots(figsize=(10, 5))
    plt.plot(l2, test_acc, label="Testing Accuracy")
    plt.plot(l2, train_acc, label="Training Accuracy")
    plt.xticks(l2,l)
    plt.grid(True)
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title('Accuracy versus Epoch CNN Model', fontsize=12)
    plt.show()

# %% [markdown]
# ## 1. Dataset Preparation - SVHN for Training and MNIST for Testing

# %%
# Load dataset
training_data = datasets.SVHN(
    root=DATA_DIR,
    split='train',
    download=True,
    transform = T.Compose([
        T.Resize((28,28)),
        T.Grayscale(),
        T.ToTensor(),
        T.Normalize([0.5],[0.5])
    ])
)
test_data = datasets.MNIST(
    root=DATA_DIR, 
    train=False, 
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)
# Out:
# Using downloaded and verified file: ../data/train_32x32.mat

# %%
# Create data loaders
train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %% [markdown]
# Show the MNIST dataset

# %%
grid_tr = vu.set_grid(train_dataloader.dataset.data, num_cells=56)
vu.show(grid_tr)

# %%
grid_ts = vu.set_grid(test_dataloader.dataset.data, num_cells=56)
vu.show(grid_ts)

# %% [markdown]
# In this case study, both training data and test data are from the same domain - MNIST datasets. Therefore, as we can see, both data are quite similar in terms of its representation.

# %% [markdown]
# # 2. Modeling

# %% [markdown]
# The model that will be used is **CNN** or Convolutional Neural Network.
#
# For the loss/objective function, **Cross Entropy Loss** will be used. This loss function is used mainly because in our training, model weights will be adjusted in every epoch.
#
# For the optimizer, **Adam** will be used in the model development.

# %% [markdown]
# ### 2.1. Create the model

# %%
print(f"Using {DEVICE} device")

# Define model
cnn = mu.ConvNet(d_out=10).to(DEVICE) # Use CovNet for MNIST
print(cnn)

# Persistent file to store the model
model_path_adam = os.path.join(MODEL_DIR, "cnn_mnist_svhn_adam.pth")
# Out:
# Using cpu device
# ConvNet(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=128, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# ### 2.2. Define the loss function and the optimizers

# %%
# Loss function: Cross Entropy Loss or Log Loss
loss_fn = nn.CrossEntropyLoss()

# %%
# # Optimizer 1: Stochastic Gradient Descent (SGD)
# optimizer1 = optim.SGD(
#     cnn.parameters(), 
#     lr=LEARNING_RATE
# )

# %%
# Optimizer 2: Adam
optimizer2 = optim.Adam(
    cnn.parameters(), 
    lr=LEARNING_RATE
)

# %% [markdown]
# ### 2.3. Execute the training for both experiments
# Experiment #1: using SGD as optimizer
#
# Experiment #2: using Adam as optimizer
#
# with **10** epochs for each experiment, **64** batch size, and **0.001** learning rate

# %% [markdown]
# #### 2.3.1. Using Adam as optimizer

# %%
test_accuracy_adam = []
train_accuracy_adam = []
for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train(train_dataloader, cnn, loss_fn, optimizer2)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    print("Test Set Error:")
    acc_test = tu.test(test_dataloader, cnn, loss_fn)
    print("\nTrain Set Error:")
    acc_train = tu.test(train_dataloader, cnn, loss_fn)
    test_accuracy_adam.append(acc_test)
    train_accuracy_adam.append(acc_train)
    
    # Save model
    torch.save(cnn.state_dict(), model_path_adam)
    print(f"Model {model_path_adam} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 10
#  ------------
# Loss: 2.298208 [    0]/73257
# Loss: 1.493425 [ 6400]/73257
# Loss: 0.782529 [12800]/73257
# Loss: 0.661902 [19200]/73257
# Loss: 0.527480 [25600]/73257
# Loss: 0.559309 [32000]/73257
# Loss: 0.407596 [38400]/73257
# Loss: 0.835042 [44800]/73257
# Loss: 0.560320 [51200]/73257
# Loss: 0.415149 [57600]/73257
# Loss: 0.591371 [64000]/73257
# Loss: 0.574656 [70400]/73257
#  > Training time: 162.10 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 56.0%, Avg loss: 2.122225
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.420086
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 2 out of 10
#  ------------
# Loss: 0.346479 [    0]/73257
# Loss: 0.423890 [ 6400]/73257
# Loss: 0.518599 [12800]/73257
# Loss: 0.430660 [19200]/73257
# Loss: 0.362637 [25600]/73257
# Loss: 0.462482 [32000]/73257
# Loss: 0.318983 [38400]/73257
# Loss: 0.719875 [44800]/73257
# Loss: 0.408850 [51200]/73257
# Loss: 0.279116 [57600]/73257
# Loss: 0.444184 [64000]/73257
# Loss: 0.420202 [70400]/73257
#  > Training time: 162.96 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 57.1%, Avg loss: 2.495504
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.349222
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 3 out of 10
#  ------------
# Loss: 0.210448 [    0]/73257
# Loss: 0.338239 [ 6400]/73257
# Loss: 0.437911 [12800]/73257
# Loss: 0.460760 [19200]/73257
# Loss: 0.282997 [25600]/73257
# Loss: 0.408207 [32000]/73257
# Loss: 0.247754 [38400]/73257
# Loss: 0.703536 [44800]/73257
# Loss: 0.297253 [51200]/73257
# Loss: 0.191729 [57600]/73257
# Loss: 0.366627 [64000]/73257
# Loss: 0.404350 [70400]/73257
#  > Training time: 160.69 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 55.3%, Avg loss: 3.230892
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.319735
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 4 out of 10
#  ------------
# Loss: 0.177735 [    0]/73257
# Loss: 0.306187 [ 6400]/73257
# Loss: 0.368776 [12800]/73257
# Loss: 0.443344 [19200]/73257
# Loss: 0.235301 [25600]/73257
# Loss: 0.336709 [32000]/73257
# Loss: 0.212419 [38400]/73257
# Loss: 0.610002 [44800]/73257
# Loss: 0.272507 [51200]/73257
# Loss: 0.148904 [57600]/73257
# Loss: 0.362898 [64000]/73257
# Loss: 0.346984 [70400]/73257
#  > Training time: 159.69 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 53.6%, Avg loss: 4.039123
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.279858
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 5 out of 10
#  ------------
# Loss: 0.196047 [    0]/73257
# Loss: 0.357435 [ 6400]/73257
# Loss: 0.345814 [12800]/73257
# Loss: 0.368266 [19200]/73257
# Loss: 0.220060 [25600]/73257
# Loss: 0.344204 [32000]/73257
# Loss: 0.193918 [38400]/73257
# Loss: 0.442225 [44800]/73257
# Loss: 0.252476 [51200]/73257
# Loss: 0.139597 [57600]/73257
# Loss: 0.197802 [64000]/73257
# Loss: 0.320500 [70400]/73257
#  > Training time: 162.88 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 54.9%, Avg loss: 4.461453
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.266544
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 6 out of 10
#  ------------
# Loss: 0.117600 [    0]/73257
# Loss: 0.308277 [ 6400]/73257
# Loss: 0.263371 [12800]/73257
# Loss: 0.314694 [19200]/73257
# Loss: 0.251897 [25600]/73257
# Loss: 0.321820 [32000]/73257
# Loss: 0.175811 [38400]/73257
# Loss: 0.419950 [44800]/73257
# Loss: 0.224458 [51200]/73257
# Loss: 0.136373 [57600]/73257
# Loss: 0.103196 [64000]/73257
# Loss: 0.312016 [70400]/73257
#  > Training time: 161.42 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 58.8%, Avg loss: 4.360471
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.248480
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 7 out of 10
#  ------------
# Loss: 0.098006 [    0]/73257
# Loss: 0.210133 [ 6400]/73257
# Loss: 0.301601 [12800]/73257
# Loss: 0.389453 [19200]/73257
# Loss: 0.216875 [25600]/73257
# Loss: 0.351298 [32000]/73257
# Loss: 0.156308 [38400]/73257
# Loss: 0.247273 [44800]/73257
# Loss: 0.229460 [51200]/73257
# Loss: 0.095982 [57600]/73257
# Loss: 0.151518 [64000]/73257
# Loss: 0.209741 [70400]/73257
#  > Training time: 166.18 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 54.0%, Avg loss: 5.629005
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.229202
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 8 out of 10
#  ------------
# Loss: 0.117243 [    0]/73257
# Loss: 0.172925 [ 6400]/73257
# Loss: 0.297929 [12800]/73257
# Loss: 0.313413 [19200]/73257
# Loss: 0.151958 [25600]/73257
# Loss: 0.193559 [32000]/73257
# Loss: 0.115534 [38400]/73257
# Loss: 0.314777 [44800]/73257
# Loss: 0.131836 [51200]/73257
# Loss: 0.086643 [57600]/73257
# Loss: 0.124984 [64000]/73257
# Loss: 0.254532 [70400]/73257
#  > Training time: 150.52 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 55.4%, Avg loss: 5.853723
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.213888
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 9 out of 10
#  ------------
# Loss: 0.151605 [    0]/73257
# Loss: 0.223896 [ 6400]/73257
# Loss: 0.318731 [12800]/73257
# Loss: 0.227673 [19200]/73257
# Loss: 0.123903 [25600]/73257
# Loss: 0.150325 [32000]/73257
# Loss: 0.123540 [38400]/73257
# Loss: 0.284549 [44800]/73257
# Loss: 0.186078 [51200]/73257
# Loss: 0.054095 [57600]/73257
# Loss: 0.079739 [64000]/73257
# Loss: 0.160747 [70400]/73257
#  > Training time: 142.61 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 53.3%, Avg loss: 6.087642
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.211073
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Epoch 10 out of 10
#  ------------
# Loss: 0.048364 [    0]/73257
# Loss: 0.157301 [ 6400]/73257
# Loss: 0.234963 [12800]/73257
# Loss: 0.279772 [19200]/73257
# Loss: 0.105824 [25600]/73257
# Loss: 0.199621 [32000]/73257
# Loss: 0.126138 [38400]/73257
# Loss: 0.272719 [44800]/73257
# Loss: 0.085924 [51200]/73257
# Loss: 0.082719 [57600]/73257
# Loss: 0.039553 [64000]/73257
# Loss: 0.171835 [70400]/73257
#  > Training time: 142.21 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 57.4%, Avg loss: 7.112591
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.189425
#
# Model models/cnn_mnist_svhn_adam.pth stored!
# Done!

# %% [markdown]
# **Experiment** result: from the above training and testing executions, it can be seen that the accuracy of the CNN model with Adam optimizer (10 epochs, 64 batch size, and 0.001 learning rate) is 57.4%.

# %% [markdown]
# ##### 2.3.1.1. Plotting Training Accuracy vs Test Accuracy

# %%
plot_acc_epoch(EPOCHS, train_accuracy_adam, test_accuracy_adam)

# %% [markdown]
# It can be seen from the plot above that CNN with Adam optimizer performs really good, however, it is slightly overfitting the training set.
