# %%
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

from torchvision import datasets
import torchvision.transforms as T

# %%
# Created modules
import visualization_utils as vu
import train_utils as tu
import model_utils as mu

import imp
imp.reload(mu)
imp.reload(tu)
# Out:
# <module 'train_utils' from '/Users/intanmaharani/Desktop/Semester I August 2022/IF5171 - Pembelajaran Mesin DSAI/Deep Learning/Praktikum_Mandiri/Project1/deliverables/train_utils.py'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 0. Defining Costants

# %%
DATA_DIR = "../data"
MODEL_DIR = "models"

EPOCHS = 10
BATCH_SIZE = 64
LEARNING_RATE = 1e-3

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
## Create the directory to store the model if not exists
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# Plotting Helper Function
def plot_acc_epoch(epochs, train_acc, test_acc):
    l = range(1,epochs+1)
    N = len(l)
    l2 = np.arange(N)
    plt.subplots(figsize=(10, 5))
    plt.plot(l2, test_acc, label="Testing Accuracy")
    plt.plot(l2, train_acc, label="Training Accuracy")
    plt.xticks(l2,l)
    plt.grid(True)
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title('Accuracy versus Epoch CNN Model', fontsize=12)
    plt.show()

# %% [markdown]
# ## 1. Dataset Preparation - MNIST for Both Training and Testing

# %%
# Load dataset
training_data = datasets.MNIST(
    root=DATA_DIR, 
    train=True, 
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

test_data = datasets.MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

# %%
# Create data loaders
train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %% [markdown]
# Show the MNIST dataset

# %%
grid_tr = vu.set_grid(train_dataloader.dataset.data, num_cells=56)
vu.show(grid_tr)

# %%
grid_ts = vu.set_grid(test_dataloader.dataset.data, num_cells=56)
vu.show(grid_ts)

# %% [markdown]
# In this case study, both training data and test data are from the same domain - MNIST datasets. Therefore, as we can see, both data are quite similar in terms of its representation.

# %% [markdown]
# # 2. Modeling

# %% [markdown]
# The model that will be used is **CNN** or Convolutional Neural Network.
#
# For the loss/objective function, **Cross Entropy Loss** will be used. This loss function is used mainly because in our training, model weights will be adjusted in every epoch.
#
# For the optimizer, both **Stochastic Gradient Descent (SGD)** and **Adam** will be experimented in the model development. In which, we can see later on which optimizer performs better to predict the given MNIST test set.

# %% [markdown]
# ### 2.1. Create the model

# %%
print(f"Using {DEVICE} device")

# Define model
cnn_sgd = mu.ConvNet(d_out=10).to(DEVICE)
print(cnn_sgd)

# Define model
cnn_adam = mu.ConvNet(d_out=10).to(DEVICE)
print(cnn_adam)

# Persistent file to store the model
model_path_sgd = os.path.join(MODEL_DIR, "cnn_mnist_mnist_sgd.pth")
model_path_adam = os.path.join(MODEL_DIR, "cnn_mnist_mnist_adam.pth")
# Out:
# Using cpu device
# ConvNet(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=128, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )
# ConvNet(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (max_pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=128, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# ### 2.2. Define the loss function and the optimizers

# %%
# Loss function: Cross Entropy Loss or Log Loss
loss_fn = nn.CrossEntropyLoss()

# %%
# Optimizer 1: Stochastic Gradient Descent (SGD)
optimizer1 = optim.SGD(
    cnn_sgd.parameters(), 
    lr=LEARNING_RATE
)

# %%
# Optimizer 2: Adam
optimizer2 = optim.Adam(
    cnn_adam.parameters(), 
    lr=LEARNING_RATE
)

# %% [markdown]
# ### 2.3. Execute the training for both experiments
# Experiment #1: using SGD as optimizer
#
# Experiment #2: using Adam as optimizer
#
# with **10** epochs for each experiment, **64** batch size, and **0.001** learning rate

# %% [markdown]
# #### 2.3.1. Using SGD as optimizer

# %%
test_accuracy_sgd = []
train_accuracy_sgd = []
for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train(train_dataloader, cnn_sgd, loss_fn, optimizer1)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    print("Test Set Error:")
    acc_test = tu.test(test_dataloader, cnn_sgd, loss_fn)
    print("\nTrain Set Error:")
    acc_train = tu.test(train_dataloader, cnn_sgd, loss_fn)
    test_accuracy_sgd.append(acc_test)
    train_accuracy_sgd.append(acc_train)
    
    # Save model
    torch.save(cnn_sgd.state_dict(), model_path_sgd)
    print(f"Model {model_path_sgd} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 10
#  ------------
# Loss: 2.307225 [    0]/60000
# Loss: 2.307459 [ 6400]/60000
# Loss: 2.295495 [12800]/60000
# Loss: 2.312948 [19200]/60000
# Loss: 2.305426 [25600]/60000
# Loss: 2.302881 [32000]/60000
# Loss: 2.299583 [38400]/60000
# Loss: 2.292943 [44800]/60000
# Loss: 2.302797 [51200]/60000
# Loss: 2.299686 [57600]/60000
#  > Training time: 113.45 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 10.3%, Avg loss: 2.296091
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 10.5%, Avg loss: 2.295916
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 2 out of 10
#  ------------
# Loss: 2.297244 [    0]/60000
# Loss: 2.296714 [ 6400]/60000
# Loss: 2.289669 [12800]/60000
# Loss: 2.296591 [19200]/60000
# Loss: 2.296177 [25600]/60000
# Loss: 2.294558 [32000]/60000
# Loss: 2.286617 [38400]/60000
# Loss: 2.287286 [44800]/60000
# Loss: 2.287468 [51200]/60000
# Loss: 2.280346 [57600]/60000
#  > Training time: 111.03 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 17.6%, Avg loss: 2.281463
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 17.5%, Avg loss: 2.281575
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 3 out of 10
#  ------------
# Loss: 2.281386 [    0]/60000
# Loss: 2.279705 [ 6400]/60000
# Loss: 2.277058 [12800]/60000
# Loss: 2.265302 [19200]/60000
# Loss: 2.274912 [25600]/60000
# Loss: 2.275165 [32000]/60000
# Loss: 2.253891 [38400]/60000
# Loss: 2.262873 [44800]/60000
# Loss: 2.243480 [51200]/60000
# Loss: 2.223996 [57600]/60000
#  > Training time: 114.17 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 51.5%, Avg loss: 2.232889
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 51.6%, Avg loss: 2.234003
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 4 out of 10
#  ------------
# Loss: 2.231911 [    0]/60000
# Loss: 2.218869 [ 6400]/60000
# Loss: 2.216432 [12800]/60000
# Loss: 2.149402 [19200]/60000
# Loss: 2.162257 [25600]/60000
# Loss: 2.149768 [32000]/60000
# Loss: 2.052570 [38400]/60000
# Loss: 2.044438 [44800]/60000
# Loss: 1.861673 [51200]/60000
# Loss: 1.675323 [57600]/60000
#  > Training time: 111.25 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 71.9%, Avg loss: 1.604723
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 71.5%, Avg loss: 1.619228
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 5 out of 10
#  ------------
# Loss: 1.629730 [    0]/60000
# Loss: 1.209715 [ 6400]/60000
# Loss: 1.044974 [12800]/60000
# Loss: 0.786820 [19200]/60000
# Loss: 0.733530 [25600]/60000
# Loss: 0.689413 [32000]/60000
# Loss: 0.558024 [38400]/60000
# Loss: 0.651397 [44800]/60000
# Loss: 0.647701 [51200]/60000
# Loss: 0.592408 [57600]/60000
#  > Training time: 108.89 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.510805
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.543652
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 6 out of 10
#  ------------
# Loss: 0.576759 [    0]/60000
# Loss: 0.387836 [ 6400]/60000
# Loss: 0.393616 [12800]/60000
# Loss: 0.422805 [19200]/60000
# Loss: 0.447326 [25600]/60000
# Loss: 0.470229 [32000]/60000
# Loss: 0.343068 [38400]/60000
# Loss: 0.510605 [44800]/60000
# Loss: 0.487638 [51200]/60000
# Loss: 0.471910 [57600]/60000
#  > Training time: 121.85 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.391460
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.420099
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 7 out of 10
#  ------------
# Loss: 0.439826 [    0]/60000
# Loss: 0.332721 [ 6400]/60000
# Loss: 0.294092 [12800]/60000
# Loss: 0.362525 [19200]/60000
# Loss: 0.352090 [25600]/60000
# Loss: 0.411851 [32000]/60000
# Loss: 0.252144 [38400]/60000
# Loss: 0.450845 [44800]/60000
# Loss: 0.396656 [51200]/60000
# Loss: 0.397885 [57600]/60000
#  > Training time: 113.58 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.331861
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.356370
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 8 out of 10
#  ------------
# Loss: 0.354558 [    0]/60000
# Loss: 0.299891 [ 6400]/60000
# Loss: 0.239451 [12800]/60000
# Loss: 0.338857 [19200]/60000
# Loss: 0.292935 [25600]/60000
# Loss: 0.359868 [32000]/60000
# Loss: 0.207840 [38400]/60000
# Loss: 0.412510 [44800]/60000
# Loss: 0.344600 [51200]/60000
# Loss: 0.347617 [57600]/60000
#  > Training time: 127.20 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.290299
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.312104
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 9 out of 10
#  ------------
# Loss: 0.295541 [    0]/60000
# Loss: 0.272037 [ 6400]/60000
# Loss: 0.199057 [12800]/60000
# Loss: 0.328622 [19200]/60000
# Loss: 0.253531 [25600]/60000
# Loss: 0.310139 [32000]/60000
# Loss: 0.177696 [38400]/60000
# Loss: 0.383477 [44800]/60000
# Loss: 0.305101 [51200]/60000
# Loss: 0.312059 [57600]/60000
#  > Training time: 138.54 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.258781
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.278338
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Epoch 10 out of 10
#  ------------
# Loss: 0.249171 [    0]/60000
# Loss: 0.245477 [ 6400]/60000
# Loss: 0.175857 [12800]/60000
# Loss: 0.324296 [19200]/60000
# Loss: 0.217270 [25600]/60000
# Loss: 0.274881 [32000]/60000
# Loss: 0.158024 [38400]/60000
# Loss: 0.355566 [44800]/60000
# Loss: 0.279193 [51200]/60000
# Loss: 0.288057 [57600]/60000
#  > Training time: 134.40 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.233653
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.251560
#
# Model models/cnn_mnist_mnist_sgd.pth stored!
# Done!

# %% [markdown]
# **Experiment #1** result: From the above training and test executions, it can be seen that the accuracy of the CNN model with SGD optimizer (10 epochs, 64 batch size, and 0.001 learning rate) is 92.7% (sometimes changed when re-run).

# %% [markdown]
# ##### 2.3.1.1. Plotting Training Accuracy vs Test Accuracy

# %%
plot_acc_epoch(EPOCHS, train_accuracy_sgd, test_accuracy_sgd)

# %% [markdown]
# #### 2.3.2. Using Adam as optimizer

# %%
test_accuracy_adam = []
train_accuracy_adam = []
for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train(train_dataloader, cnn_adam, loss_fn, optimizer2)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    print("Test Set Error:")
    acc_test = tu.test(test_dataloader, cnn_adam, loss_fn)
    print("\nTrain Set Error:")
    acc_train = tu.test(train_dataloader, cnn_adam, loss_fn)
    test_accuracy_adam.append(acc_test)
    train_accuracy_adam.append(acc_train)
    
    # Save model
    torch.save(cnn_adam.state_dict(), model_path_adam)
    print(f"Model {model_path_adam} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 10
#  ------------
# Loss: 2.310097 [    0]/60000
# Loss: 0.212460 [ 6400]/60000
# Loss: 0.164305 [12800]/60000
# Loss: 0.185441 [19200]/60000
# Loss: 0.037130 [25600]/60000
# Loss: 0.064795 [32000]/60000
# Loss: 0.068856 [38400]/60000
# Loss: 0.132749 [44800]/60000
# Loss: 0.204545 [51200]/60000
# Loss: 0.140961 [57600]/60000
#  > Training time: 123.12 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.061407
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.063053
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 2 out of 10
#  ------------
# Loss: 0.030610 [    0]/60000
# Loss: 0.152049 [ 6400]/60000
# Loss: 0.050326 [12800]/60000
# Loss: 0.021811 [19200]/60000
# Loss: 0.032369 [25600]/60000
# Loss: 0.031087 [32000]/60000
# Loss: 0.081075 [38400]/60000
# Loss: 0.072907 [44800]/60000
# Loss: 0.173665 [51200]/60000
# Loss: 0.168218 [57600]/60000
#  > Training time: 127.01 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.082085
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.065960
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 3 out of 10
#  ------------
# Loss: 0.031479 [    0]/60000
# Loss: 0.090868 [ 6400]/60000
# Loss: 0.035771 [12800]/60000
# Loss: 0.016567 [19200]/60000
# Loss: 0.024568 [25600]/60000
# Loss: 0.033466 [32000]/60000
# Loss: 0.024378 [38400]/60000
# Loss: 0.077076 [44800]/60000
# Loss: 0.080476 [51200]/60000
# Loss: 0.042278 [57600]/60000
#  > Training time: 145.34 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.063927
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.043250
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 4 out of 10
#  ------------
# Loss: 0.007375 [    0]/60000
# Loss: 0.018368 [ 6400]/60000
# Loss: 0.096044 [12800]/60000
# Loss: 0.017084 [19200]/60000
# Loss: 0.023218 [25600]/60000
# Loss: 0.072830 [32000]/60000
# Loss: 0.024488 [38400]/60000
# Loss: 0.028648 [44800]/60000
# Loss: 0.083968 [51200]/60000
# Loss: 0.113663 [57600]/60000
#  > Training time: 122.67 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.080409
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.056933
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 5 out of 10
#  ------------
# Loss: 0.007444 [    0]/60000
# Loss: 0.071202 [ 6400]/60000
# Loss: 0.035785 [12800]/60000
# Loss: 0.071556 [19200]/60000
# Loss: 0.029176 [25600]/60000
# Loss: 0.068467 [32000]/60000
# Loss: 0.002610 [38400]/60000
# Loss: 0.002471 [44800]/60000
# Loss: 0.063881 [51200]/60000
# Loss: 0.009928 [57600]/60000
#  > Training time: 116.83 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.071666
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.040224
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 6 out of 10
#  ------------
# Loss: 0.009459 [    0]/60000
# Loss: 0.000926 [ 6400]/60000
# Loss: 0.006737 [12800]/60000
# Loss: 0.002263 [19200]/60000
# Loss: 0.033445 [25600]/60000
# Loss: 0.035424 [32000]/60000
# Loss: 0.004753 [38400]/60000
# Loss: 0.013801 [44800]/60000
# Loss: 0.082554 [51200]/60000
# Loss: 0.079709 [57600]/60000
#  > Training time: 125.97 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.049231
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.025755
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 7 out of 10
#  ------------
# Loss: 0.031558 [    0]/60000
# Loss: 0.022031 [ 6400]/60000
# Loss: 0.023263 [12800]/60000
# Loss: 0.036050 [19200]/60000
# Loss: 0.001569 [25600]/60000
# Loss: 0.005528 [32000]/60000
# Loss: 0.000960 [38400]/60000
# Loss: 0.092932 [44800]/60000
# Loss: 0.054778 [51200]/60000
# Loss: 0.002276 [57600]/60000
#  > Training time: 126.10 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.057851
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.021843
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 8 out of 10
#  ------------
# Loss: 0.023123 [    0]/60000
# Loss: 0.004219 [ 6400]/60000
# Loss: 0.006748 [12800]/60000
# Loss: 0.005937 [19200]/60000
# Loss: 0.005315 [25600]/60000
# Loss: 0.001529 [32000]/60000
# Loss: 0.000370 [38400]/60000
# Loss: 0.002175 [44800]/60000
# Loss: 0.015318 [51200]/60000
# Loss: 0.032416 [57600]/60000
#  > Training time: 127.72 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.063656
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.023282
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 9 out of 10
#  ------------
# Loss: 0.002544 [    0]/60000
# Loss: 0.098194 [ 6400]/60000
# Loss: 0.028265 [12800]/60000
# Loss: 0.004376 [19200]/60000
# Loss: 0.003217 [25600]/60000
# Loss: 0.132509 [32000]/60000
# Loss: 0.002713 [38400]/60000
# Loss: 0.001276 [44800]/60000
# Loss: 0.011749 [51200]/60000
# Loss: 0.022983 [57600]/60000
#  > Training time: 125.14 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.058759
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.4%, Avg loss: 0.018161
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Epoch 10 out of 10
#  ------------
# Loss: 0.011796 [    0]/60000
# Loss: 0.011293 [ 6400]/60000
# Loss: 0.017926 [12800]/60000
# Loss: 0.002880 [19200]/60000
# Loss: 0.024100 [25600]/60000
# Loss: 0.013875 [32000]/60000
# Loss: 0.023701 [38400]/60000
# Loss: 0.062808 [44800]/60000
# Loss: 0.070503 [51200]/60000
# Loss: 0.008833 [57600]/60000
#  > Training time: 131.93 seconds
# Test Set Error:
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.060233
#
#
# Train Set Error:
# Test Error:
#  Accuracy: 99.3%, Avg loss: 0.021427
#
# Model models/cnn_mnist_mnist_adam.pth stored!
# Done!

# %% [markdown]
# **Experiment #2** result: from the above training and testing executions, it can be seen that the accuracy of the CNN model with Adam optimizer (10 epochs, 64 batch size, and 0.001 learning rate) is 98.8% (sometimes changed when re-run). Much better than using SGD as an optimizer.

# %% [markdown]
# ##### 2.3.2.1. Plotting Training Accuracy vs Test Accuracy

# %%
plot_acc_epoch(EPOCHS, train_accuracy_adam, test_accuracy_adam)

# %% [markdown]
# It can be seen from the plot above that CNN with Adam optimizer performs really good, however, it is slightly overfitting the training set.
